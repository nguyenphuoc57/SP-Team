# %%
import keras, os
import numpy as np
from keras.models import Model
from keras.layers import Dense
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image

import PIL
from io import BytesIO
from IPython.display import display, Image

from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import Flatten

# %%
trdata = ImageDataGenerator(rescale=(1/255))
traindata = trdata.flow_from_directory(directory="/content/drive/MyDrive/Dataset_Apple_and_Oranges/train/",target_size=(224,224))
tsdata = ImageDataGenerator(1/255)
testdata=tsdata.flow_from_directory(directory='/content/drive/MyDrive/Dataset_Apple_and_Oranges/test',target_size=(224,224))
# Out:
# Found 2014 images belonging to 2 classes.
# Found 514 images belonging to 2 classes.

# %%
from keras.applications.vgg19 import VGG19
vggmodel = VGG19(weights='imagenet',include_top=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574717952/574710816 [==============================] - 6s 0us/step
# 574726144/574710816 [==============================] - 6s 0us/step

# %%
vggmodel.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layers in (vggmodel.layers)[:23]:
  print(layers)
  layers.trainable = False
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f1804adc310>
# <keras.layers.convolutional.Conv2D object at 0x7f1803566650>
# <keras.layers.convolutional.Conv2D object at 0x7f1803566cd0>
# <keras.layers.pooling.MaxPooling2D object at 0x7f1803286210>
# <keras.layers.convolutional.Conv2D object at 0x7f1803288a50>
# <keras.layers.convolutional.Conv2D object at 0x7f18032863d0>
# <keras.layers.pooling.MaxPooling2D object at 0x7f1802813290>
# <keras.layers.convolutional.Conv2D object at 0x7f1802815a50>
# <keras.layers.convolutional.Conv2D object at 0x7f180281d7d0>
# <keras.layers.convolutional.Conv2D object at 0x7f1803290cd0>
# <keras.layers.convolutional.Conv2D object at 0x7f1802824b90>
# <keras.layers.pooling.MaxPooling2D object at 0x7f180282dc10>
# <keras.layers.convolutional.Conv2D object at 0x7f1802821e50>
# <keras.layers.convolutional.Conv2D object at 0x7f1802834a10>
# <keras.layers.convolutional.Conv2D object at 0x7f1802841090>
# <keras.layers.convolutional.Conv2D object at 0x7f1802837810>
# <keras.layers.pooling.MaxPooling2D object at 0x7f180284a5d0>
# <keras.layers.convolutional.Conv2D object at 0x7f180284ed50>
# <keras.layers.convolutional.Conv2D object at 0x7f18027d3a10>
# <keras.layers.convolutional.Conv2D object at 0x7f1802847750>
# <keras.layers.convolutional.Conv2D object at 0x7f18027dbed0>
# <keras.layers.pooling.MaxPooling2D object at 0x7f18027e3f10>
# <keras.layers.core.Flatten object at 0x7f18027db890>

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
X=vggmodel.layers[-2].output
predictions = Dense(2,activation="softmax")(X)
model_final=Model(inputs= vggmodel.input,outputs= predictions)

# %%
model_final.compile(loss="categorical_crossentropy",
                    optimizer= optimizers.SGD(learning_rate=0.01, momentum=0.9),metrics=["accuracy"])

# %%
model_final.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense (Dense)                (None, 2)                 8194
# =================================================================
# Total params: 139,578,434
# Trainable params: 119,554,050
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint ,EarlyStopping
checkpoint = ModelCheckpoint("vgg19_1.h5",monitor='val_accuracy',verbose=1, save_best_file_only=False,save_weights_only=True,mode='auto',peroid=1)
early = EarlyStopping(monitor='val_accuracy',min_delta=0,patience=40,verbose=1,mode='auto')
hist = model_final.fit_generator(generator= traindata, steps_per_epoch=2, epochs=100, verbose=1, validation_data= testdata, validation_steps=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 2/2 [==============================] - ETA: 0s - loss: 5.8006 - accuracy: 0.5000
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# 2/2 [==============================] - 86s 30s/step - loss: 7.4589 - accuracy: 0.5104 - val_loss: 2.0939 - val_accuracy: 0.5469
# Epoch 2/100
# 2/2 [==============================] - 43s 34s/step - loss: 1.9315 - accuracy: 0.5208 - val_loss: 1.7653 - val_accuracy: 0.5312
# Epoch 3/100
# 2/2 [==============================] - 33s 26s/step - loss: 0.6869 - accuracy: 0.5208 - val_loss: 1.4461 - val_accuracy: 0.4219
# Epoch 4/100
# 2/2 [==============================] - 29s 20s/step - loss: 0.6981 - accuracy: 0.5417 - val_loss: 0.8800 - val_accuracy: 0.5625
# Epoch 5/100
# 2/2 [==============================] - 29s 20s/step - loss: 0.6918 - accuracy: 0.5104 - val_loss: 1.1526 - val_accuracy: 0.5156
# Epoch 6/100
# 2/2 [==============================] - 24s 18s/step - loss: 0.7163 - accuracy: 0.3542 - val_loss: 0.7713 - val_accuracy: 0.5469
# Epoch 7/100
# 2/2 [==============================] - 23s 15s/step - loss: 0.6889 - accuracy: 0.5833 - val_loss: 0.7988 - val_accuracy: 0.5625
# Epoch 8/100
# 2/2 [==============================] - 20s 13s/step - loss: 0.6880 - accuracy: 0.5521 - val_loss: 1.1068 - val_accuracy: 0.6250
# Epoch 9/100
# 2/2 [==============================] - 24s 17s/step - loss: 0.6811 - accuracy: 0.5958 - val_loss: 1.5321 - val_accuracy: 0.4531
# Epoch 10/100
# 2/2 [==============================] - 19s 12s/step - loss: 0.7154 - accuracy: 0.4896 - val_loss: 0.8196 - val_accuracy: 0.5312
# Epoch 11/100
# 2/2 [==============================] - 18s 13s/step - loss: 0.6904 - accuracy: 0.5312 - val_loss: 0.9226 - val_accuracy: 0.5781
# Epoch 12/100
# 2/2 [==============================] - 15s 10s/step - loss: 0.6927 - accuracy: 0.5208 - val_loss: 0.8236 - val_accuracy: 0.5625
# Epoch 13/100
# 2/2 [==============================] - 14s 8s/step - loss: 0.6852 - accuracy: 0.6354 - val_loss: 0.8919 - val_accuracy: 0.7188
# Epoch 14/100
# 2/2 [==============================] - 16s 11s/step - loss: 0.6453 - accuracy: 0.6771 - val_loss: 1.0188 - val_accuracy: 0.5156
# Epoch 15/100
# 2/2 [==============================] - 13s 8s/step - loss: 0.6908 - accuracy: 0.5417 - val_loss: 0.7350 - val_accuracy: 0.5312
# Epoch 16/100
# 2/2 [==============================] - 11s 6s/step - loss: 0.7339 - accuracy: 0.4688 - val_loss: 0.8366 - val_accuracy: 0.5000
# Epoch 17/100
# 2/2 [==============================] - 11s 7s/step - loss: 0.6974 - accuracy: 0.3542 - val_loss: 0.9493 - val_accuracy: 0.5312
# Epoch 18/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.8278 - val_accuracy: 0.5312
# Epoch 19/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.6948 - accuracy: 0.3646 - val_loss: 0.9178 - val_accuracy: 0.4688
# Epoch 20/100
# 2/2 [==============================] - 7s 3s/step - loss: 0.6930 - accuracy: 0.5104 - val_loss: 1.0515 - val_accuracy: 0.4375
# Epoch 21/100
# 2/2 [==============================] - 12s 4s/step - loss: 0.6941 - accuracy: 0.4688 - val_loss: 0.8177 - val_accuracy: 0.5469
# Epoch 22/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.6901 - accuracy: 0.5938 - val_loss: 0.8923 - val_accuracy: 0.4688
# Epoch 23/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.6954 - accuracy: 0.4563 - val_loss: 0.7301 - val_accuracy: 0.5938
# Epoch 24/100
# 2/2 [==============================] - 7s 5s/step - loss: 0.6981 - accuracy: 0.4167 - val_loss: 1.0424 - val_accuracy: 0.4375
# Epoch 25/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.6941 - accuracy: 0.4896 - val_loss: 0.9299 - val_accuracy: 0.5312
# Epoch 26/100
# 2/2 [==============================] - 7s 3s/step - loss: 0.6964 - accuracy: 0.4375 - val_loss: 0.9161 - val_accuracy: 0.4844
# Epoch 27/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.6961 - accuracy: 0.4271 - val_loss: 0.9343 - val_accuracy: 0.4688
# Epoch 28/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.6907 - accuracy: 0.5938 - val_loss: 0.8941 - val_accuracy: 0.5156
# Epoch 29/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.6930 - accuracy: 0.5104 - val_loss: 0.7062 - val_accuracy: 0.6250
# Epoch 30/100
# 2/2 [==============================] - 6s 2s/step - loss: 0.6949 - accuracy: 0.3229 - val_loss: 0.8545 - val_accuracy: 0.4688
# Epoch 31/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.6930 - accuracy: 0.5208 - val_loss: 0.9317 - val_accuracy: 0.5000
# Epoch 32/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.6902 - accuracy: 0.6146 - val_loss: 0.8387 - val_accuracy: 0.5156
# Epoch 33/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6982 - accuracy: 0.3854 - val_loss: 0.8293 - val_accuracy: 0.4844
# Epoch 34/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.6899 - accuracy: 0.5729 - val_loss: 1.0988 - val_accuracy: 0.4531
# Epoch 35/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.6889 - accuracy: 0.5729 - val_loss: 0.7610 - val_accuracy: 0.5938
# Epoch 36/100
# 2/2 [==============================] - 4s 3s/step - loss: 0.6900 - accuracy: 0.5521 - val_loss: 0.8200 - val_accuracy: 0.5156
# Epoch 37/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.6878 - accuracy: 0.5729 - val_loss: 0.8055 - val_accuracy: 0.5625
# Epoch 38/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.6925 - accuracy: 0.5208 - val_loss: 0.8780 - val_accuracy: 0.4688
# Epoch 39/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.6890 - accuracy: 0.5521 - val_loss: 1.0068 - val_accuracy: 0.4375
# Epoch 40/100
# 2/2 [==============================] - 4s 3s/step - loss: 0.6970 - accuracy: 0.4792 - val_loss: 0.8122 - val_accuracy: 0.5312
# Epoch 41/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.6924 - accuracy: 0.5208 - val_loss: 0.8029 - val_accuracy: 0.5312
# Epoch 42/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.6999 - accuracy: 0.4583 - val_loss: 0.7497 - val_accuracy: 0.4844
# Epoch 43/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.6972 - accuracy: 0.4792 - val_loss: 0.8456 - val_accuracy: 0.5156
# Epoch 44/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.6878 - accuracy: 0.5625 - val_loss: 0.7523 - val_accuracy: 0.5938
# Epoch 45/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.6925 - accuracy: 0.5208 - val_loss: 0.7041 - val_accuracy: 0.6562
# Epoch 46/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.6963 - accuracy: 0.4792 - val_loss: 0.9763 - val_accuracy: 0.4531
# Epoch 47/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.6961 - accuracy: 0.4792 - val_loss: 0.7985 - val_accuracy: 0.5000
# Epoch 48/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.6914 - accuracy: 0.5312 - val_loss: 0.9578 - val_accuracy: 0.4844
# Epoch 49/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.6866 - accuracy: 0.5938 - val_loss: 0.8285 - val_accuracy: 0.4844
# Epoch 50/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.6963 - accuracy: 0.4688 - val_loss: 0.8310 - val_accuracy: 0.5469
# Epoch 51/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.6927 - accuracy: 0.5208 - val_loss: 0.8578 - val_accuracy: 0.5156
# Epoch 52/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.6972 - accuracy: 0.4583 - val_loss: 0.8138 - val_accuracy: 0.5469
# Epoch 53/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.6902 - accuracy: 0.5521 - val_loss: 0.7470 - val_accuracy: 0.5469
# Epoch 54/100
# 2/2 [==============================] - 3s 711ms/step - loss: 0.6958 - accuracy: 0.4688 - val_loss: 0.9465 - val_accuracy: 0.5000
# Epoch 55/100
# 2/2 [==============================] - 2s 916ms/step - loss: 0.6956 - accuracy: 0.4688 - val_loss: 0.9659 - val_accuracy: 0.5312
# Epoch 56/100
# 2/2 [==============================] - 2s 2s/step - loss: 0.6996 - accuracy: 0.3958 - val_loss: 0.6880 - val_accuracy: 0.6094
# Epoch 57/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.6976 - accuracy: 0.4062 - val_loss: 0.9270 - val_accuracy: 0.3906
# Epoch 58/100
# 2/2 [==============================] - 1s 552ms/step - loss: 0.6948 - accuracy: 0.4479 - val_loss: 0.8521 - val_accuracy: 0.5156
# Epoch 59/100
# 2/2 [==============================] - 2s 796ms/step - loss: 0.6934 - accuracy: 0.5208 - val_loss: 0.8839 - val_accuracy: 0.4375
# Epoch 60/100
# 2/2 [==============================] - 1s 706ms/step - loss: 0.6933 - accuracy: 0.4254 - val_loss: 0.9441 - val_accuracy: 0.5000
# Epoch 61/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.6934 - accuracy: 0.5000 - val_loss: 0.9582 - val_accuracy: 0.4062
# Epoch 62/100
# 2/2 [==============================] - 1s 1s/step - loss: 0.6935 - accuracy: 0.4375 - val_loss: 0.9122 - val_accuracy: 0.4375
# Epoch 63/100
# 2/2 [==============================] - 2s 2s/step - loss: 0.6932 - accuracy: 0.4688 - val_loss: 1.0655 - val_accuracy: 0.4219
# Epoch 64/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.6929 - accuracy: 0.5312 - val_loss: 1.0018 - val_accuracy: 0.4688
# Epoch 65/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.6952 - accuracy: 0.3958 - val_loss: 0.8946 - val_accuracy: 0.4844
# Epoch 66/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.6905 - accuracy: 0.6354 - val_loss: 0.9357 - val_accuracy: 0.3594
# Epoch 67/100
# 2/2 [==============================] - 2s 970ms/step - loss: 0.6946 - accuracy: 0.4479 - val_loss: 0.9259 - val_accuracy: 0.4688
# Epoch 68/100
# 2/2 [==============================] - 2s 773ms/step - loss: 0.6921 - accuracy: 0.5417 - val_loss: 0.6965 - val_accuracy: 0.6250
# Epoch 69/100
# 2/2 [==============================] - 1s 652ms/step - loss: 0.6919 - accuracy: 0.5417 - val_loss: 0.9241 - val_accuracy: 0.4219
# Epoch 70/100
# 2/2 [==============================] - 2s 2s/step - loss: 0.6884 - accuracy: 0.6354 - val_loss: 0.8506 - val_accuracy: 0.5000
# Epoch 71/100
# 2/2 [==============================] - 1s 615ms/step - loss: 0.7001 - accuracy: 0.3646 - val_loss: 0.8479 - val_accuracy: 0.4688
# Epoch 72/100
# 2/2 [==============================] - 1s 696ms/step - loss: 0.6939 - accuracy: 0.4896 - val_loss: 0.9069 - val_accuracy: 0.4844
# Epoch 73/100
# 2/2 [==============================] - 1s 936ms/step - loss: 0.6921 - accuracy: 0.5312 - val_loss: 0.7671 - val_accuracy: 0.5625
# Epoch 74/100
# 2/2 [==============================] - 1s 551ms/step - loss: 0.6961 - accuracy: 0.4271 - val_loss: 0.7906 - val_accuracy: 0.5000
# Epoch 75/100
# 2/2 [==============================] - 1s 636ms/step - loss: 0.6927 - accuracy: 0.5208 - val_loss: 0.8095 - val_accuracy: 0.5625
# Epoch 76/100
# 2/2 [==============================] - 1s 550ms/step - loss: 0.6930 - accuracy: 0.5104 - val_loss: 0.9158 - val_accuracy: 0.4844
# Epoch 77/100
# 2/2 [==============================] - 1s 550ms/step - loss: 0.6951 - accuracy: 0.4271 - val_loss: 0.8988 - val_accuracy: 0.5625
# Epoch 78/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.6930 - accuracy: 0.5104 - val_loss: 0.9098 - val_accuracy: 0.5156
# Epoch 79/100
# 2/2 [==============================] - 1s 643ms/step - loss: 0.6937 - accuracy: 0.4688 - val_loss: 0.8880 - val_accuracy: 0.3906
# Epoch 80/100
# 2/2 [==============================] - 1s 556ms/step - loss: 0.6942 - accuracy: 0.4167 - val_loss: 0.9776 - val_accuracy: 0.3594
# Epoch 81/100
# 2/2 [==============================] - 2s 818ms/step - loss: 0.6930 - accuracy: 0.5521 - val_loss: 1.0396 - val_accuracy: 0.4375
# Epoch 82/100
# 2/2 [==============================] - 1s 553ms/step - loss: 0.6933 - accuracy: 0.5521 - val_loss: 0.8814 - val_accuracy: 0.5312
# Epoch 83/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.6936 - accuracy: 0.4688 - val_loss: 0.9170 - val_accuracy: 0.4688
# Epoch 84/100
# 2/2 [==============================] - 1s 738ms/step - loss: 0.6927 - accuracy: 0.5312 - val_loss: 0.9892 - val_accuracy: 0.4688
# Epoch 85/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.6920 - accuracy: 0.5521 - val_loss: 0.9494 - val_accuracy: 0.4844
# Epoch 86/100
# 2/2 [==============================] - 2s 968ms/step - loss: 0.6918 - accuracy: 0.5417 - val_loss: 0.9912 - val_accuracy: 0.4688
# Epoch 87/100
# 2/2 [==============================] - 1s 551ms/step - loss: 0.6980 - accuracy: 0.3854 - val_loss: 1.0097 - val_accuracy: 0.4844
# Epoch 88/100
# 2/2 [==============================] - 1s 705ms/step - loss: 0.6905 - accuracy: 0.5625 - val_loss: 0.9301 - val_accuracy: 0.4219
# Epoch 89/100
# 2/2 [==============================] - 1s 553ms/step - loss: 0.6934 - accuracy: 0.5000 - val_loss: 1.0485 - val_accuracy: 0.4531
# Epoch 90/100
# 2/2 [==============================] - 1s 714ms/step - loss: 0.7025 - accuracy: 0.3438 - val_loss: 0.8714 - val_accuracy: 0.5312
# Epoch 91/100
# 2/2 [==============================] - 1s 758ms/step - loss: 0.6890 - accuracy: 0.5833 - val_loss: 1.0546 - val_accuracy: 0.4531
# Epoch 92/100
# 2/2 [==============================] - 1s 551ms/step - loss: 0.6976 - accuracy: 0.4271 - val_loss: 0.8509 - val_accuracy: 0.5469
# Epoch 93/100
# 2/2 [==============================] - 1s 845ms/step - loss: 0.6951 - accuracy: 0.4688 - val_loss: 0.7219 - val_accuracy: 0.5781
# Epoch 94/100
# 2/2 [==============================] - 1s 1s/step - loss: 0.6898 - accuracy: 0.5833 - val_loss: 0.7954 - val_accuracy: 0.5938
# Epoch 95/100
# 2/2 [==============================] - 1s 552ms/step - loss: 0.6948 - accuracy: 0.4688 - val_loss: 0.9521 - val_accuracy: 0.5156
# Epoch 96/100
# 2/2 [==============================] - 1s 558ms/step - loss: 0.6952 - accuracy: 0.4583 - val_loss: 0.8718 - val_accuracy: 0.4531
# Epoch 97/100
# 2/2 [==============================] - 1s 548ms/step - loss: 0.6938 - accuracy: 0.4896 - val_loss: 0.9579 - val_accuracy: 0.4844
# Epoch 98/100
# 2/2 [==============================] - 1s 556ms/step - loss: 0.6953 - accuracy: 0.4375 - val_loss: 1.0007 - val_accuracy: 0.4375
# Epoch 99/100
# 2/2 [==============================] - 1s 620ms/step - loss: 0.6934 - accuracy: 0.4896 - val_loss: 0.8480 - val_accuracy: 0.5156
# Epoch 100/100
# 2/2 [==============================] - 1s 554ms/step - loss: 0.6920 - accuracy: 0.5938 - val_loss: 0.9353 - val_accuracy: 0.4844

# %%
model_final.save('/content/drive/MyDrive/VGGsave')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/VGGsave/assets

# %%
#Run this first
from tensorflow import keras
model_temp = keras.models.load_model('/content/drive/MyDrive/VGGsave')

# %%
#Save the final weights after training
model_final.save_weights("vgg19_1.h5")

# %%
#To visualise the training/validation accuracy and loss
import matplotlib.pyplot as plt
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model_accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","Loss","Validation Loss"])
plt.show()

# %%
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model 

#Load the final model for data testing/prediction 
saved_model= model_final.save_weights("vgg19_1.h5")
#saved_model = Load_model("vgg19_1.h5")

# %%
from io import BytesIO
import PIL
from IPython.display import display, Image 
from keras.preprocessing.image import load_img
from skimage import io
import numpy as np
import pandas as pd
import cv2 as cv 
from google.colab.patches import cv2_imshow
#Display testing data and label below 
def display_img_array(ima):
  im = PIL.Image.fromarray(ima)
  bio=BytesIO()
  im.save(bio, format='png')
  display(Image(bio.getvalue(), format='png'))

urls = "https://suckhoedoisong.vn/Images/haiyen/2018/12/10/tao.jpg"
img_temp = io.imread(urls)
image_2 = cv.cvtColor(img_temp, cv.COLOR_RGB2BGR)
image = cv.resize(image_2,(224,224))
display_img_array(image)
image=np.expand_dims(image,axis=0)
output=model_final.predict(image)
if output[0][0] > output[0][1]:
  print("orange")
else:
  print("apple")
# Out:
# orange

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras.models import Model, load_model
#drive.mount('/content/drive')
model = model_final
weight_kernel = model.layers[1].weights[0].numpy()
print(weight_kernel)
# Out:
# [[[[ 0.34119523  0.09563112  0.0177449  ... -0.11436455 -0.05099866
#     -0.00299793]
#    [ 0.46418372  0.03355668  0.10245045 ... -0.06945956 -0.04020201
#      0.04048637]
#    [ 0.39416704 -0.08419707 -0.03631314 ... -0.10720515 -0.03804016
#      0.04690642]]
#
#   [[ 0.33999205  0.13363543  0.02129423 ... -0.13025227 -0.16508926
#     -0.06969624]
#    [ 0.41810837  0.05260524  0.09755926 ... -0.09385028 -0.20492788
#     -0.0573062 ]
#    [ 0.37740308 -0.07876257 -0.04775979 ... -0.11827433 -0.19008617
#     -0.01889699]]
#
#   [[-0.04484424  0.06471398 -0.07631404 ... -0.12629718 -0.29905206
#     -0.2825364 ]
#    [-0.04806903 -0.00658076 -0.02234544 ... -0.0878844  -0.3915486
#     -0.34632796]
#    [-0.04594866 -0.11583115 -0.14462094 ... -0.12290562 -0.35782176
#     -0.27979308]]]
#
#
#  [[[ 0.23215917  0.133657    0.12134422 ... -0.1063385   0.28406844
#      0.3594997 ]
#    [ 0.30511212  0.05677647  0.21688674 ... -0.06828708  0.3440761
#      0.44033417]
#    [ 0.2671299  -0.07969447  0.05988706 ... -0.09225675  0.31764674
#      0.42209673]]
#
#   [[ 0.08978214  0.18505956  0.15264879 ... -0.04266965  0.25779948
#      0.35873157]
#    [ 0.10385381  0.08851637  0.2392226  ... -0.01210995  0.27064082
#      0.40848857]
#    [ 0.09986369 -0.06240906  0.07442063 ... -0.02214639  0.25912452
#      0.423499  ]]
#
#   [[-0.30331427  0.08002605 -0.03926321 ... -0.12958746 -0.19778992
#     -0.21510386]
#    [-0.37314063 -0.00698938  0.02153259 ... -0.09827439 -0.2535741
#     -0.25541356]
#    [-0.34100872 -0.13399366 -0.11510294 ... -0.11911335 -0.23109646
#     -0.19202407]]]
#
#
#  [[[-0.07260918  0.10084777  0.01313597 ... -0.12594968  0.1464741
#      0.05009392]
#    [-0.07646758  0.03879711  0.09974211 ... -0.08732687  0.2247974
#      0.10158388]
#    [-0.07573577 -0.07806503 -0.03540679 ... -0.1208065   0.20088433
#      0.09790061]]
#
#   [[-0.246675    0.1414054   0.02605635 ... -0.10128672  0.16340195
#      0.02832468]
#    [-0.3107071   0.06031388  0.10412455 ... -0.06832542  0.20279962
#      0.05222717]
#    [-0.2803425  -0.07094654 -0.0387974  ... -0.08843154  0.18996507
#      0.07766484]]
#
#   [[-0.33683276  0.06601517 -0.08144748 ... -0.13460518 -0.1342358
#     -0.27096185]
#    [-0.46453714 -0.00576723 -0.02660675 ... -0.10017379 -0.15603794
#     -0.32566148]
#    [-0.41602272 -0.11491341 -0.14672887 ... -0.13079506 -0.1379628
#     -0.2658845 ]]]]

# %%
#Bias Print
import ctypes
import struct
def float_to_bin(num):
    return format(struct.unpack('!I', struct.pack('!f', num))[0], '032b')

for layers in model_final.layers:
  a=str(layers.name)
  if 'conv' in a:
    w= layers.weights[1].numpy()
    with open(layers.name + ".txt".format(layers),"w") as temp:
      for x in w:
        temp.write(float_to_bin(x))
        temp.write("\n")

# %%
#Nháp
for layers in model_final.layers:
  a=str(layers.name)
  if "conv" in a:
   print(a)
# Out:
# block1_conv1
# block1_conv2
# block2_conv1
# block2_conv2
# block3_conv1
# block3_conv2
# block3_conv3
# block3_conv4
# block4_conv1
# block4_conv2
# block4_conv3
# block4_conv4
# block5_conv1
# block5_conv2
# block5_conv3
# block5_conv4

# %%
#Nháp
for layers in model_final.layers:
  a=str(layers.name)
  if "bias" in a:
   print(a)

# %%
#Kernel Print
from keras.models import Model, load_model
import ctypes
import struct
def float_to_bin(num):
    return format(struct.unpack('!I', struct.pack('!f', num))[0], '032b')
#drive.mount('/content/drive')
model = model_temp
weight_kernel = model.layers[1].weights[0].numpy()
matrix=[]
#for x in weight_kernel:
 #for i in x:
  # a=[]
   #a.append(x)
   #for i in a:
     #matrix.append(i)
#print(matrix)
for layers in model.layers :
  a=str(layers.name)
  if 'conv' in a:
    w= layers.weights[0].numpy()
    with open(layers.name + ".txt".format(layers),"w") as temp:
     for x in w:
      for y in x:
        for a in y:
          for b in a:
           temp.write(float_to_bin(b))
           temp.write("\n")
